# %% [markdown]
# BPE(BYTE PAIR ENCODING ) TOKENIZER

# %%
import importlib
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("gpt2")
text = (
    "Hello , do you like tea?  In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
output = tokenizer.decode(integers)
print (output)
print(integers)
# Out:
# Hello , do you like tea?  In the sunlit terracesof someunknownPlace.
# [15496, 837, 466, 345, 588, 8887, 30, 220, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]
